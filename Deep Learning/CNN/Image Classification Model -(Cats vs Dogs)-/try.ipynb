# %%
import tensorflow as tf
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 print(tf.reduce_sum(tf.random.normal([1000, 1000])))
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\__init__.py:42
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#      41 _os.environ['TF2_BEHAVIOR'] = '1'
# ---> 42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
#      45 from ._api.v2 import __internal__
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\tf2.py:21
#       1 # Copyright 2018 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
# ...
