# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779357403.799897    2203 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779357404.200364    2203 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779357405.908193    2203 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
train_ds = keras.utils.image_dataset_from_directory(
    image_paths='train',
    labels="inferred",
    label_mode='int',
    batch_size=32,
    image_size=(256, 256)
)


validation_ds = keras.utils.image_dataset_from_directory(
    image_paths='test',
    labels="inferred",
    label_mode='int',
    batch_size=32,
    image_size=(256, 256)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 train_ds = keras.utils.image_dataset_from_directory(
#       2     image_paths='train',
#       3     labels="inferred",
#       4     label_mode='int',
#
# TypeError: image_dataset_from_directory() got an unexpected keyword argument 'image_paths'

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory='train',
    labels='inferred',
    label_mode='int',
    image_size=(256,256),
    batch_size=32
)
# Out:
# Found 0 files belonging to 0 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train_ds = keras.utils.image_dataset_from_directory(
#       2     directory='train',
#       3     labels='inferred',
#       4     label_mode='int',
#
# File ~/miniconda3/envs/dl-GPU/lib/python3.13/site-packages/keras/src/utils/image_dataset_utils.py:372, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     368 image_paths, labels = dataset_utils.get_training_or_validation_split(
#     369     image_paths, labels, validation_split, subset
#     370 )
#     371 if not image_paths:
# --> 372     raise ValueError(
#     373         f"No images found in directory {directory}. "
#     374         f"Allowed formats: {ALLOWLIST_FORMATS}"
#     375     )
#     377 dataset = paths_and_labels_to_dataset(
#     378     image_paths=image_paths,
#     379     image_size=image_size,
#    (...)    391     format=format,
#     392 )
#     394 if format == "tf":
#
# ValueError: No images found in directory train. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')
