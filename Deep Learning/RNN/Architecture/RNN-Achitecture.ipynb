# %%
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3, input_shape=(4,5)))
model.add(Dense(1, activation="sigmoid"))

model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1780142457.685483    5879 gpu_device.cc:2431] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# W0000 00:00:1780142457.687159    5879 gpu_device.cc:2431] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# I0000 00:00:1780142457.801524    5879 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5262 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 12.0
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[3], line 3
#       1 model = Sequential()
# ----> 3 model.add(SimpleRNN(3, input_shape=(4,5)))
#       4 model.add(Dense(1, activation="sigmoid"))
#       6 model.summary()
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/rnn/simple_rnn.py:321, in SimpleRNN.__init__(self, units, activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, return_sequences, return_state, go_backwards, stateful, unroll, seed, **kwargs)
#     296 def __init__(
#     297     self,
#     298     units,
#    (...)
#     319     **kwargs,
#     320 ):
# --> 321     cell = SimpleRNNCell(
#     322         units,
#     323         activation=activation,
#     324         use_bias=use_bias,
#     325         kernel_initializer=kernel_initializer,
#     326         recurrent_initializer=recurrent_initializer,
#     327         bias_initializer=bias_initializer,
#     328         kernel_regularizer=kernel_regularizer,
#     329         recurrent_regularizer=recurrent_regularizer,
#     330         bias_regularizer=bias_regularizer,
#     331         kernel_constraint=kernel_constraint,
#     332         recurrent_constraint=recurrent_constraint,
#     333         bias_constraint=bias_constraint,
#     334         dropout=dropout,
#     335         recurrent_dropout=recurrent_dropout,
#     336         seed=seed,
#     337         dtype=kwargs.get("dtype", None),
#     338         trainable=kwargs.get("trainable", True),
#     339         name="simple_rnn_cell",
#     340     )
#     341     super().__init__(
#     342         cell,
#     343         return_sequences=return_sequences,
#    (...)
#     348         **kwargs,
#     349     )
#     350     self.input_spec = [InputSpec(ndim=3)]
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/rnn/simple_rnn.py:105, in SimpleRNNCell.__init__(self, units, activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, kernel_regularizer, recurrent_regularizer, bias_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, seed, **kwargs)
#     103 super().__init__(**kwargs)
#     104 self.seed = seed
# --> 105 self.seed_generator = backend.random.SeedGenerator(seed)
#     107 self.units = units
#     108 self.activation = activations.get(activation)
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/random/seed_generator.py:87, in SeedGenerator.__init__(self, seed, name, **kwargs)
#      84     return self.backend.convert_to_tensor([seed, 0], dtype=dtype)
#      86 with self.backend.name_scope(self.name, caller=self):
# ---> 87     self.state = self.backend.Variable(
#      88         seed_initializer,
#      89         shape=(2,),
#      90         dtype=self.backend.random_seed_dtype(),
#      91         trainable=False,
#      92         aggregation="none",
#      93         name="seed_generator_state",
#      94     )
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/common/variables.py:206, in Variable.__init__(***failed resolving arguments***)
#     204 if callable(initializer):
#     205     self._shape = self._validate_shape(shape)
# --> 206     self._initialize_with_initializer(initializer)
#     207 else:
#     208     self._initialize(initializer)
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py:52, in Variable._initialize_with_initializer(self, initializer)
#      51 def _initialize_with_initializer(self, initializer):
# ---> 52     self._initialize(lambda: initializer(self._shape, dtype=self._dtype))
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py:42, in Variable._initialize(self, value)
#      40     self._value = value
#      41 else:
# ---> 42     self._value = tf.Variable(
#      43         value,
#      44         dtype=self._dtype,
#      45         trainable=self.trainable,
#      46         name=self.name,
#      47         aggregation=self._map_aggregation(self.aggregation),
#      48         synchronization=self._map_synchronization(self.synchronization),
#      49     )
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py:52, in Variable._initialize_with_initializer.<locals>.<lambda>()
#      51 def _initialize_with_initializer(self, initializer):
# ---> 52     self._initialize(lambda: initializer(self._shape, dtype=self._dtype))
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/random/seed_generator.py:84, in SeedGenerator.__init__.<locals>.seed_initializer(*args, **kwargs)
#      82 def seed_initializer(*args, **kwargs):
#      83     dtype = kwargs.get("dtype", None)
# ---> 84     return self.backend.convert_to_tensor([seed, 0], dtype=dtype)
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py:152, in convert_to_tensor(x, dtype, sparse, ragged)
#     147     if dtype == "bool" or is_int_dtype(dtype):
#     148         # TensorFlow conversion is stricter than other backends, it does not
#     149         # allow ints for bools or floats for ints. We convert without dtype
#     150         # and cast instead.
#     151         x = tf.convert_to_tensor(x)
# --> 152         return tf.cast(x, dtype)
#     153     return tf.convert_to_tensor(x, dtype=dtype)
#     154 elif dtype is not None and not standardize_dtype(x.dtype) == dtype:
#
# InternalError: {{function_node __wrapped__Cast_device_/job:localhost/replica:0/task:0/device:GPU:0}} 'cuLaunchKernel(function, gridX, gridY, gridZ, blockX, blockY, blockZ, 0, reinterpret_cast<CUstream>(stream), params, nullptr)' failed with 'CUDA_ERROR_INVALID_HANDLE' [Op:Cast] name:
