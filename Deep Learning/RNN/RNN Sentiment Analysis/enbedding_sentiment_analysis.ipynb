# %%
docs = ['go india',
    'india india',
    'hip hip hurray',
    'jeetega bhai jeetega india',
    'bharat mata ki jai',
    'kohli kohli',
    'sachin sachin',
    'modi ji ki jai',
    'inqulab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'india': 1,
#  'hip': 2,
#  'jeetega': 3,
#  'ki': 4,
#  'jai': 5,
#  'kohli': 6,
#  'sachin': 7,
#  'go': 8,
#  'hurray': 9,
#  'bhai': 10,
#  'bharat': 11,
#  'mata': 12,
#  'modi': 13,
#  'ji': 14,
#  'inqulab': 15,
#  'zindabad': 16}

# %%
len(tokenizer.word_index)
# Out:
# 16

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[8, 1],
#  [1, 1],
#  [2, 2, 9],
#  [3, 10, 3, 1],
#  [11, 12, 4, 5],
#  [6, 6],
#  [7, 7],
#  [13, 14, 4, 5],
#  [15, 16]]

# %%
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences,padding='post')

# %%
sequences
# Out:
# array([[ 8,  1,  0,  0],
#        [ 1,  1,  0,  0],
#        [ 2,  2,  9,  0],
#        [ 3, 10,  3,  1],
#        [11, 12,  4,  5],
#        [ 6,  6,  0,  0],
#        [ 7,  7,  0,  0],
#        [13, 14,  4,  5],
#        [15, 16,  0,  0]], dtype=int32)

# %%
from keras.datasets import imdb
from keras import Sequential 
from keras.layers import Dense, SimpleRNN, Embedding, Flatten

# %%
model = Sequential()

model.add(Embedding(17,output_dim=2, input_length=5))


model.summary()
# Out:
# /home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf

with tf.device('/GPU:0'):
    x = tf.random.normal((10, 50, 1))

print(x.shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1780425820.562387    1909 gpu_device.cc:2431] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# W0000 00:00:1780425820.564155    1909 gpu_device.cc:2431] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# I0000 00:00:1780425820.677716    1909 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5262 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 12.0
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[12], line 4
#       1 import tensorflow as tf
#       3 with tf.device('/GPU:0'):
# ----> 4     x = tf.random.normal((10, 50, 1))
#       6 print(x.shape)
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:6027, in raise_from_not_ok_status(e, name)
#    6025 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6026   e.message += (" name: " + str(name if name is not None else ""))
# -> 6027   raise core._status_to_exception(e) from None
#
# InternalError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} 'cuLaunchKernel(function, gridX, gridY, gridZ, blockX, blockY, blockZ, 0, reinterpret_cast<CUstream>(stream), params, nullptr)' failed with 'CUDA_ERROR_INVALID_HANDLE' [Op:Mul] name:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense

layer = Dense(10)

x = tf.random.normal((32, 20))

print(layer(x))

# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU'))

a = tf.random.normal((5000, 5000))
b = tf.random.normal((5000, 5000))

c = tf.matmul(a, b)

print(c.shape)

# %%
import tensorflow as tf
tf.debugging.set_log_device_placement(True)

with tf.device('/GPU:0'):
    x = tf.random.normal((10, 50, 1))
    print(x.device)
    print(x.shape)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[13], line 5
#       2 tf.debugging.set_log_device_placement(True)
#       4 with tf.device('/GPU:0'):
# ----> 5     x = tf.random.normal((10, 50, 1))
#       6     print(x.device)
#       7     print(x.shape)
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:6027, in raise_from_not_ok_status(e, name)
#    6025 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6026   e.message += (" name: " + str(name if name is not None else ""))
# -> 6027   raise core._status_to_exception(e) from None
#
# InternalError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} 'cuLaunchKernel(function, gridX, gridY, gridZ, blockX, blockY, blockZ, 0, reinterpret_cast<CUstream>(stream), params, nullptr)' failed with 'CUDA_ERROR_INVALID_HANDLE' [Op:Mul] name:

# %%
import sys
print(sys.executable)
# Out:
# /home/opera/miniconda3/envs/dlgpu/bin/python

# %%
# Out:
# []

# %%
# Out:
#   Cell In[4], line 1
#     python -c "import tensorflow as tf; print(tf.__version__); print(tf.config.list_physical_devices('GPU'))"
#               ^
# SyntaxError: invalid syntax

# %%
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[8], line 5
#       1 import tensorflow as tf
#       3 print(tf.config.list_physical_devices('GPU'))
# ----> 5 a = tf.random.normal((5000,5000))
#       6 b = tf.random.normal((5000,5000))
#       8 c = tf.matmul(a,b)
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:6027, in raise_from_not_ok_status(e, name)
#    6025 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6026   e.message += (" name: " + str(name if name is not None else ""))
# -> 6027   raise core._status_to_exception(e) from None
#
# InternalError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} 'cuLaunchKernel(function, gridX, gridY, gridZ, blockX, blockY, blockZ, 0, reinterpret_cast<CUstream>(stream), params, nullptr)' failed with 'CUDA_ERROR_INVALID_HANDLE' [Op:Mul] name:

# %%
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[7], line 5
#       2 import time
#       4 with tf.device('/GPU:0'):
# ----> 5     a = tf.random.normal([5000, 5000])
#       6     b = tf.random.normal([5000, 5000])
#       8 start = time.time()
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:6027, in raise_from_not_ok_status(e, name)
#    6025 def raise_from_not_ok_status(e, name) -> NoReturn:
#    6026   e.message += (" name: " + str(name if name is not None else ""))
# -> 6027   raise core._status_to_exception(e) from None
#
# InternalError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} 'cuLaunchKernel(function, gridX, gridY, gridZ, blockX, blockY, blockZ, 0, reinterpret_cast<CUstream>(stream), params, nullptr)' failed with 'CUDA_ERROR_INVALID_HANDLE' [Op:Mul] name:
