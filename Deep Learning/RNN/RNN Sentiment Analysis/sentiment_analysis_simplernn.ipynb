# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Embedding
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
model = Sequential()
model.add(Embedding(17,output_dim=2,input_length=5))

model.summary()
# Out:
# /home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pred = model.predict(sequences)
#       2 print(pred)
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_9_1/embedding_7_1/GatherV2 defined at (most recent call last):
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/traitlets/config/application.py", line 1082, in launch_instance
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_11986/2269839758.py", line 1, in <module>
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 588, in predict
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 282, in one_step_on_data_distributed
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 125, in wrapper
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 271, in one_step_on_data
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 110, in predict_step
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/models/sequential.py", line 220, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/models/functional.py", line 183, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/function.py", line 206, in _run_through_graph
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/models/functional.py", line 655, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/core/embedding.py", line 158, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/numpy.py", line 6193, in take
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/numpy.py", line 2589, in take
#
# indices[9,1] = 17 is not in [0, 17)
# 	 [[{{node sequential_9_1/embedding_7_1/GatherV2}}]] [Op:__inference_one_step_on_data_distributed_9234]

# %%
from keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train.shape
# Out:
# (25000, 50)

# %%
model = Sequential()
model.add(Embedding(10000, 2))
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_6 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[45], line 2
#       1 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
# ----> 2 history = model.fit(X_train, y_train,epochs=5,validation_data=(X_test,y_test))
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_8_1/embedding_6_1/GatherV2 defined at (most recent call last):
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/traitlets/config/application.py", line 1082, in launch_instance
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_11986/863240012.py", line 2, in <module>
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 399, in fit
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 241, in function
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 154, in multi_step_on_iterator
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 125, in wrapper
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 134, in one_step_on_data
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 59, in train_step
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/models/sequential.py", line 220, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/models/functional.py", line 183, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/function.py", line 206, in _run_through_graph
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/models/functional.py", line 655, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/layers/core/embedding.py", line 158, in call
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/ops/numpy.py", line 6193, in take
#
#   File "/home/opera/miniconda3/envs/dlgpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/numpy.py", line 2589, in take
#
# indices[1,38] = 10383 is not in [0, 10000)
# 	 [[{{node sequential_8_1/embedding_6_1/GatherV2}}]] [Op:__inference_multi_step_on_iterator_9073]
